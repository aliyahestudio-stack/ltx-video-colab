# %% [markdown]
# <a href="https://colab.research.google.com/github/aliyahestudio-stack/ltx-video-colab/blob/main/video_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🎬 LTX-Video Colab - Vídeos de 20s reais no Free
#
# Notebook limpo pra gerar vídeos com LTX-Video.
# Rode as células na ordem.
